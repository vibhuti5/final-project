# %% [markdown]
# ### Delete input files if they are already available

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def delfile(file):
    import os
    try:
        os.remove(file)
    except OSError:
        pass

# %%
delfile("intent.md")
delfile("query.md")
delfile("agri.yml")
delfile("config.yml")

# %% [markdown]
# ### Load data from Indian Government's Agriculture API
#
# #### Note: You need to create a login at data.gov.in and generate an API key

# %%
import requests
api_key = r"579b464db66ec23bdd000001dbba9a854ca84a9b6d93cbcc5f51d998"
outputformat = r"json"
records = 5000
request = r'https://api.data.gov.in/catalog/19ba71d9-6d58-402d-9b75-a0ebdc034a56?api-key='+api_key+'&format='+outputformat+'&limit='+str(records)
response = requests.get(request)
data = eval(response.text)

# %% [markdown]
# ### Verify the data loaded

# %%
data['records'][4999]
# Out:
# {'Season': 'NA',
#  'Sector': 'AGRICULTURE',
#  'Category': 'Others',
#  'Crop': 'Others',
#  'QueryType': 'Government Schemes',
#  'QueryText': 'ask about general information',
#  'KccAns': 'all information provided - thanks for calling in kisan call centre',
#  'StateName': 'GUJARAT',
#  'DistrictName': 'BANAS KANTHA',
#  'BlockName': 'VAV',
#  'CreatedOn': '2018-05-01T17:50:06.15'}

# %% [markdown]
# ### Extract required data into lists

# %%
category = []
crop = []
querytype = []
querytext = []
kccans = []
identifier = []

for i in range(0,1000):
    category.append(data['records'][i]['Category'])
    crop.append(data['records'][i]['Crop'])
    querytype.append(data['records'][i]['QueryType'])
    identifier.append(i)
    querytext.append(data['records'][i]['QueryText'])
    kccans.append(data['records'][i]['KccAns'])

# %% [markdown]
# ### Create a dataframe and load the above lists into dataframe columns

# %%
import pandas as pd
df = pd.DataFrame()

# %%
df["category"] = category
df["crop"] = crop
df["querytype"] = querytype
df["querytext"] = querytext
df["kccans"] = kccans
df['identifier'] = identifier

# %% [markdown]
# ### Preprocess each column to prepare data for intent and actions

# %%
df["intent"] = df["category"]+df["crop"]+df["querytype"]#+df["identifier"]

# %% [markdown]
# #### Function to remove special characters from the intent column

# %%
import re
def cleanString(x):
    return re.sub('[^A-Za-z0-9]+', '', x)

# %%
df["intent"] = df.apply(lambda x: cleanString(str(x["intent"])), axis =1)

# %%
df["intent_md"] = "## intent:" + df["intent"]

# %%
df["intent_*"] = "* " + df["intent"]

# %%
df["intent_-"] = "- " + df["intent"]

# %%
df["querytext_md"] = "- " + df["querytext"]

# %%
df_pivot = df.pivot_table(index=['intent_md'],
                                     values='querytext_md',
                                     aggfunc=lambda x: '\n'.join(x)).reset_index()

# %%
for i,j in zip(df_pivot["intent_md"], df_pivot["querytext_md"]):
    with open('intent.md', 'a') as f:
        print(i, '\n', j, file = f)
    f.close()

# %%
df["actions_md"] = "utter_" + df["intent"]

# %%
df["query_md"] = "## query_" + df["intent"]

# %%
df["actions_-"] = "- " + df["actions_md"]

# %%
df["actions_:"] = df["actions_md"] + ":"

# %% [markdown]
# #### Function to clean up answers

# %%
def cleanAnswer(x):
    return re.sub('[^A-Za-z0-9]+', ' ', x)

# %%
df["kccans"] = df["kccans"].replace(r'\\n','', regex=True) 
df["kccans"] = df.apply(lambda x: cleanAnswer(str(x["kccans"])), axis =1)

# %%
df["kccans_text"] = '- text: "' + df["kccans"] + '"'

# %%
df2 = df[["actions_:","kccans_text"]].drop_duplicates(["actions_:"])

# %%
df3 = df[["query_md","intent_*","actions_-"]].drop_duplicates(["intent_*"])

# %% [markdown]
# ### Create query.md to define intent and actions

# %%
for i,j,k in zip(df3["query_md"], df3["intent_*"], df3["actions_-"]):
    with open('query.md', 'a') as f:
        print(i, '\n', j, '\n',' ', k, '\n', '\n', file = f)
    f.close()

# %% [markdown]
# ### Create agri.yml to capture intent, actions and templates for answers

# %%
with open('agri.yml', 'a') as f:
        print('intents:', '\n', file = f)
f.close()

# %%
for i in df["intent_-"].unique():
    with open('agri.yml', 'a') as f:
        print(i, '\n', file = f)
    f.close()

# %%
with open('agri.yml', 'a') as f:
        print("\n", file = f)
        print("slots:\n", file = f)
        print("   group:\n", file = f)
        print("     type: text\n", file = f)
        print("\n", file = f)
        print("entities:\n", file = f)
        print("- group\n", file = f)
        print("\n", file = f)
f.close()

# %%
with open('agri.yml', 'a') as f:
        print('actions:', '\n', file = f)
f.close()

# %%
for i in df["actions_-"].unique():
    with open('agri.yml', 'a') as f:
        print(i, '\n', file = f)
    f.close()

# %%
with open('agri.yml', 'a') as f:
        #print("\n", file = f)
        print('templates:', '\n', file = f)
f.close()

# %%
for i,j in zip(df2["actions_:"],df2["kccans_text"]):
    with open('agri.yml', 'a') as f:
        print(' ',i, '\n', file = f)
        print(' ',j, '\n', file = f)
    f.close()

# %%
import rasa_nlu
import rasa_core
import spacy

# %%
config = """
language: "en"

pipeline:
- name: "nlp_spacy"                   
- name: "tokenizer_spacy"            
- name: "ner_crf"                 
- name: "intent_featurizer_spacy"    
- name: "intent_classifier_sklearn" 
- name: "ner_synonyms"                
""" 
with open('config.yml', 'a') as f:
        print(config, file = f)
        
f.close()

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# Load training data
training_data = load_data("intent.md")

# Use trainer to load configuration data the needs to be learnt by the model
trainer = Trainer(config.load("config.yml"))

# Train model on training data
interpreter = trainer.train(training_data)

# Save Model
model_directory = trainer.persist("./models/nlu")
# Out:
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   15.3s finished

# %%
# Verify your question's confidence level
import json
def pprint(o):   
    print(json.dumps(o, indent=2))
    
pprint(interpreter.parse("insect in cotton?"))
# Out:
# {
#   "intent": {
#     "name": "FiberCropsCottonKapasPlantProtection",
#     "confidence": 0.035218651357052086
#   },
#   "entities": [],
#   "intent_ranking": [
#     {
#       "name": "FiberCropsCottonKapasPlantProtection",
#       "confidence": 0.035218651357052086
#     },
#     {
#       "name": "FiberCropsCottonKapasWeather",
#       "confidence": 0.026391299062884507
#     },
#     {
#       "name": "OthersOthersWeather",
#       "confidence": 0.02567710942123305
#     },
#     {
#       "name": "FruitsMangoPlantProtection",
#       "confidence": 0.02522270149631183
#     },
#     {
#       "name": "FiberCropsCottonKapasFertilizerUseandAvailability",
#       "confidence": 0.023540140567565426
#     },
#     {
#       "name": "VegetablesBhindiOkraLadysfingerPlantProtection",
#       "confidence": 0.022249661565728537
#     },
#     {
#       "name": "CerealsPaddyDhanPlantProtection",
#       "confidence": 0.020199616710339936
#     },
#     {
#       "name": "FiberCropsCottonKapasVarieties",
#       "confidence": 0.01847487784535647
#     },
#     {
#       "name": "VegetablesBrinjalPlantProtection",
#       "confidence": 0.018395133556068276
#     },
#     {
#       "name": "OthersOthersWeedManagement",
#       "confidence": 0.01677686424313803
#     }
#   ],
#   "text": "insect in cotton?"
# }

# %% [markdown]
# ### Evaluate Model

# %%
from rasa_nlu.test import run_evaluation

run_evaluation("intent.md", model_directory)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:06<00:00, 157.94it/s]
# {'intent_evaluation': {'predictions': [{'text': 'Ask about Gernal information',
#     'intent': 'AnimalBovineCowBuffaloAnimalBreeding',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'bakri ke muh me sujan ho gai hai kya kare',
#     'intent': 'AnimalBovineCowBuffaloDiseaseManagement',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.08146350310970434},
#    {'text': 'DISEASE MANAGEMENT IN BUFFALO',
#     'intent': 'AnimalBovineCowBuffaloDiseaseManagement',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.03057552536156595},
#    {'text': 'Animal Husbandry Toll Free No.?',
#     'intent': 'AnimalBovineCowBuffaloLivestockProductsProcessingandPackaging',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.176755950796594},
#    {'text': 'POULTRY FARM INFORMATION',
#     'intent': 'AnimalPOULTRYFARMLivestockProductsProcessingandPackaging',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.05898714035939552},
#    {'text': 'ask about honey bee',
#     'intent': 'BeekeepingBeekeepingCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0592048667535789},
#    {'text': 'Ask about Gernal information',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'Information regarding weather forecasting?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7019162029303532},
#    {'text': 'Information regarding weather forecasting?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7019162029303532},
#    {'text': 'Information regarding Weather in ?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.14787950126034805},
#    {'text': 'Information regarding weather?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding weather in ?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.14787950126034805},
#    {'text': 'information regarding weather forecasting?',
#     'intent': 'CerealsBarleyJauFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7019162029303532},
#    {'text': 'Information regarding weather in ?',
#     'intent': 'CerealsOatsFieldPreparation',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.14787950126034805},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsPaddyDhanBioPesticidesandBioFertilizers',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsPaddyDhanBioPesticidesandBioFertilizers',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'paddy nutrient management:',
#     'intent': 'CerealsPaddyDhanCulturalPractices',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.038837569318369264},
#    {'text': 'FERTILISER MANGEMENT IN PADDY',
#     'intent': 'CerealsPaddyDhanFertilizerUseandAvailability',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.05189016425274309},
#    {'text': 'PADDY FERTILIZER MANAGEMENT',
#     'intent': 'CerealsPaddyDhanFertilizerUseandAvailability',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.04824079151721548},
#    {'text': 'GOVERNMENT SCHEMES',
#     'intent': 'CerealsPaddyDhanGovernmentSchemes',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.07382075314416209},
#    {'text': 'stem borer management in pddy',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.058839430405313045},
#    {'text': 'PADDY STEM YELLOW BORER MANAGEMENT',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.07444125115364705},
#    {'text': 'stem borer in paddy',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.08543642071469752},
#    {'text': 'PADDY STEM BORER MANAGEMENT',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.08004440470817568},
#    {'text': 'stem borer management in paddy',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.07742647523882133},
#    {'text': 'PADDY STEM BORER MANAGEMENT:',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.06813650473781506},
#    {'text': 'STEM BORER MANAGEMENT IN PADDY',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.07742647523882133},
#    {'text': 'leaf folder in paddy',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.07077826770631891},
#    {'text': 'Rice stem borer management',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.08004440470817568},
#    {'text': 'PADDY GREEN LEAF HOPPER MANAGEMENT',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.06768779396695322},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'MANAGEMENT OF PADDY STEM BORER',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.07080930005212642},
#    {'text': 'stem borer in paddy',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.08543642071469752},
#    {'text': 'paddy leaf folder management',
#     'intent': 'CerealsPaddyDhanPlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.06591345757919848},
#    {'text': 'Information regarding seed treatment in paddy crop ?',
#     'intent': 'CerealsPaddyDhanSeeds',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.05328183043076368},
#    {'text': 'Information regarding to seed treatment in paddy crop ?',
#     'intent': 'CerealsPaddyDhanSeeds',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0604505361912599},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsPaddyDhanSoilTesting',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'INFORMATION REGARDING OF SOIL AND WATER TESTING ?',
#     'intent': 'CerealsPaddyDhanSoilTesting',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.39858196366298276},
#    {'text': 'PADDY SOWING TIME',
#     'intent': 'CerealsPaddyDhanSowingTimeandWeather',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.05530586935563144},
#    {'text': 'Information regarding sowing time of nursury of basmati paddy ?',
#     'intent': 'CerealsPaddyDhanSowingTimeandWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.19598659168131463},
#    {'text': 'VARIETIES OF PADDY',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.11251873563520648},
#    {'text': 'asking about paddy season and varieties',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08933025185329081},
#    {'text': 'PADDY NEW VARIETIES ;',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.08250743974594593},
#    {'text': 'paddy varieties;',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.1036085862971886},
#    {'text': 'paddy varieties management',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.09082603701320703},
#    {'text': 'verity of paddy',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0783692691864632},
#    {'text': 'HYBRID VARIETIES OF PADDY FOR KHARIF SEASON',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.07993365752227138},
#    {'text': 'variety of paddy',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.07250177237651877},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'Information regarding varieties of PR-paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09043725303458422},
#    {'text': 'Information regarding varieties of PR-paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09043725303458422},
#    {'text': 'Information regarding varieties of PR-paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09043725303458422},
#    {'text': 'Information regarding varieties of Basmati paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.08300498048186718},
#    {'text': 'Information regarding varieties of Basmati paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.08300498048186718},
#    {'text': 'Information regarding varieties of PR-paddy ?',
#     'intent': 'CerealsPaddyDhanVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09043725303458422},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'CerealsPaddyDhanWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'CerealsPaddyDhanWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding Weather in Sirsa?',
#     'intent': 'CerealsPaddyDhanWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'CerealsPaddyDhanWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'CerealsPaddyDhanWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in ?',
#     'intent': 'CerealsTriticaleFieldPreparation',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.14787950126034805},
#    {'text': 'Information regarding seed treatment for nursary sowing in paddy?',
#     'intent': 'CerealsWheatBioPesticidesandBioFertilizers',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.054996260411638936},
#    {'text': 'Information regarding varieties of Basmati paddy ?',
#     'intent': 'CerealsWheatVarieties',
#     'predicted': 'CerealsPaddyDhanVarieties',
#     'confidence': 0.08300498048186718},
#    {'text': 'Weather information',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'Weather information',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'WEATHER INFORMATION',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in Sirsa ?',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in Sisa ?',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7782363721862634},
#    {'text': 'mausam ki jankari de',
#     'intent': 'CerealsWheatWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.13558199510515107},
#    {'text': 'GINGER SOWING TIME',
#     'intent': 'CondimentsandSpicesGingerCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03667335694879278},
#    {'text': 'ginger variety name',
#     'intent': 'CondimentsandSpicesGingerSeedsandPlantingMaterial',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.03457437230500398},
#    {'text': 'market information of turmeric',
#     'intent': 'CondimentsandSpicesTurmericMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.03348169315946739},
#    {'text': 'market information of turmeric',
#     'intent': 'CondimentsandSpicesTurmericMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.03348169315946739},
#    {'text': 'Turmeric\tSugandham, Guj Haldar-1 , B.S.R-1, shuroma, Prbha, Prtibha , Krishna, Rajendarsoniya, Ranga\tFirst week of May\t2800-3000 kg\\/ha\t30 X 30 Cm\t BASAL DOSE - FYM 20 \\/ T ,  NARMADA PHOS ( 300KG )',
#     'intent': 'CondimentsandSpicesTurmericSeedsandPlantingMaterial',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.20333834116171742},
#    {'text': 'How to control white fly,trips in cotton?',
#     'intent': 'FiberCropsCottonKapasBioPesticidesandBioFertilizers',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04253519553851663},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasBioPesticidesandBioFertilizers',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'Information regarding control of zinc deficiency in cotton?',
#     'intent': 'FiberCropsCottonKapasBioPesticidesandBioFertilizers',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08576940915518205},
#    {'text': 'information regarding seed treatment of cotton?',
#     'intent': 'FiberCropsCottonKapasBioPesticidesandBioFertilizers',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.03779160054962086},
#    {'text': 'Information regarding How to control white fly,thrips in cotton?',
#     'intent': 'FiberCropsCottonKapasBioPesticidesandBioFertilizers',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04573695428457062},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FiberCropsCottonKapasCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'BASAL DOSE-  12-32-16  (125KG),                                                  AMMONIUM NITRATE  (100KG)                                                                AFTER- 30, 60, 90, 105 DAYS: UREA (110KG) ,',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06464020933301011},
#    {'text': 'ASK ABOUT COTTON',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.07010137159074527},
#    {'text': 'information regarding fertilizer dose in cotton at sowing time ?',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08235233920099383},
#    {'text': 'information regarding fertilizer dose in cotton at sowing time ?',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08235233920099383},
#    {'text': 'information regarding fertilizer dose in cotton at sowing time ?',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08235233920099383},
#    {'text': 'FERTILIZER MANAGEMENT IN COTTON',
#     'intent': 'FiberCropsCottonKapasFertilizerUseandAvailability',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.04126692202959664},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FiberCropsCottonKapasFieldPreparation',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'for market information',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.06821926268056741},
#    {'text': 'MARKET INFORMATION  OF COTTON:',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.059887581634817},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'cotton market information',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION:',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.09597000060987722},
#    {'text': 'market price of cotton',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.08959739507382394},
#    {'text': 'cotton Market information',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'MARKET PRICE OF COTTON',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.08959739507382394},
#    {'text': 'COTTON MARKET INFORMATION',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.10637823429086812},
#    {'text': 'MARKET INFORMATION OF COTTON',
#     'intent': 'FiberCropsCottonKapasMarketInformation',
#     'predicted': 'FiberCropsCottonKapasMarketInformation',
#     'confidence': 0.08019953753781983},
#    {'text': 'information regarding fertilizer dose in cotton at sowing time ?',
#     'intent': 'FiberCropsCottonKapasNutrientManagement',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08235233920099383},
#    {'text': 'COTTON SUCKING PEST MANAGEMENT',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'FiberCropsCottonKapasPlantProtection',
#     'confidence': 0.03683044045603648},
#    {'text': 'Ask about pink ball warm in cotton',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.040921321593310064},
#    {'text': 'how to control leaf carl in cotton crops?',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04504912681322464},
#    {'text': 'how to control leaf carl in cotton crops?',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04504912681322464},
#    {'text': 'cotton sucking pest management',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'FiberCropsCottonKapasPlantProtection',
#     'confidence': 0.03683044045603648},
#    {'text': 'COTTON PINK BOLL WORM MANAGEMENT',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'FiberCropsCottonKapasPlantProtection',
#     'confidence': 0.03664165471822172},
#    {'text': 'COTTON PINK BOLL WORM MANAGEMENT',
#     'intent': 'FiberCropsCottonKapasPlantProtection',
#     'predicted': 'FiberCropsCottonKapasPlantProtection',
#     'confidence': 0.03664165471822172},
#    {'text': 'Information regarding soil health card ?',
#     'intent': 'FiberCropsCottonKapasSoilTesting',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.28670403737806527},
#    {'text': 'Information regarding sowing time of cotton?',
#     'intent': 'FiberCropsCottonKapasSowingTimeandWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.11593675768351476},
#    {'text': 'ask about variety',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.08397433037977249},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'Information regarding BT. cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09712885907160165},
#    {'text': 'Information regarding improved varieties of Cotton?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.08186797970095223},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'Information regarding improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.08449719509211781},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'Information regarding improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.08449719509211781},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'improved varieties of BT cotton ?',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09174978655134436},
#    {'text': 'COTTON VARAITIES',
#     'intent': 'FiberCropsCottonKapasVarieties',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.09928360462849589},
#    {'text': 'jassids management in cotton',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'FiberCropsCottonKapasWeather',
#     'confidence': 0.08377665909637082},
#    {'text': 'Information regarding weather ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding Weather in sirsa  ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7584015063937743},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding weather ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in  sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.7584015063937743},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding weather ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding improved varieties of Cotton?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'FiberCropsCottonKapasVarieties',
#     'confidence': 0.08186797970095223},
#    {'text': 'Information regarding to weather in sirsa?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding Weather in sirsa?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding to weather in sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5874957617520604},
#    {'text': 'Information regarding Weather in Sirsa ?',
#     'intent': 'FiberCropsCottonKapasWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'ASK ABOUT WEED IN COTTON',
#     'intent': 'FiberCropsCottonKapasWeedManagement',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08925575718473834},
#    {'text': 'Information regarding weed control of cotton crop ?',
#     'intent': 'FiberCropsCottonKapasWeedManagement',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.09749322118887474},
#    {'text': 'Helicoverpa management in chrysamthemum',
#     'intent': 'FlowersChrysanthemumPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0577966986792638},
#    {'text': 'CHRYSANTHEMUM LEAF EATING CATERPILLAR MANAGEMENT',
#     'intent': 'FlowersChrysanthemumPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04378186711007662},
#    {'text': 'chrysanthemum root rot management  ;',
#     'intent': 'FlowersChrysanthemumPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.047783112532948854},
#    {'text': 'HIBISCUS LEAF EATING CATTER',
#     'intent': 'FlowersHibiscusGurhalPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04320914121968771},
#    {'text': 'jasmine nutrient management ;',
#     'intent': 'FlowersJasmineNutrientManagement',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03648414428702121},
#    {'text': 'LILLIUMS NUTRIENT MANAGEMENT',
#     'intent': 'FlowersLilliumsNutrientManagement',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.0416675854905747},
#    {'text': 'LILIUMS SOWING TIME',
#     'intent': 'FlowersLilliumsPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08346338100296677},
#    {'text': 'marigold varieties',
#     'intent': 'FlowersMarigoldCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04723886647552099},
#    {'text': 'TUBEROSE STEM ROT MANAGEMENT',
#     'intent': 'FlowersTuberosePlantProtection',
#     'predicted': 'CerealsPaddyDhanPlantProtection',
#     'confidence': 0.053475351696264696},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FodderCropsBAJRANAPIERHYBRIDWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding sowing time of Gwar ?',
#     'intent': 'FodderCropsGuarSowingTimeandWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.24304741551307985},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding improved varieties of Gwar?',
#     'intent': 'FodderCropsGuarVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06554965817454052},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FodderCropsGuarWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'Information regarding weather in sirsa ?',
#     'intent': 'FodderCropsGuarWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.5872551375910837},
#    {'text': 'KRISHNA DIST A.O CONTACT NUMBER',
#     'intent': 'FodderCropsOtherTrainingandExposureVisits',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.10331526238441859},
#    {'text': 'Information regarding weather?',
#     'intent': 'FruitsAcidLimePlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'BANANA RHIZOME WEEVIL MANAGEMENT',
#     'intent': 'FruitsBananaAgricultureMechanization',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.049724870944360074},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FruitsBananaCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'banana fertilizer management',
#     'intent': 'FruitsBananaFertilizerUseandAvailability',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.047860823317477416},
#    {'text': 'banana leaf blight',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05722267702547137},
#    {'text': 'nematodes maNAGEMENT IN BANANA',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03592804154213624},
#    {'text': 'Ask about fungus problem in Root',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.037723454459373994},
#    {'text': 'Ask about fungus problem in Root',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.037723454459373994},
#    {'text': 'banana leaf spot management',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04432833636967982},
#    {'text': 'remediation for nematodes in banana crop',
#     'intent': 'FruitsBananaPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06322649269511132},
#    {'text': 'Weather Information',
#     'intent': 'FruitsBananaWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'CASEWNUT SUCKING PESTS MANAGEMENT',
#     'intent': 'FruitsChestnutPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.03911985843481198},
#    {'text': 'CITRUS FRUIT DROP MANAGEMENT',
#     'intent': 'FruitsCitrusNutrientManagement',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05852452293263302},
#    {'text': 'CITRUS MITE MANAGEMENT',
#     'intent': 'FruitsCitrusPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.044719246651611595},
#    {'text': 'CITRUS GUMMOSIS',
#     'intent': 'FruitsCitrusPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04689970935071811},
#    {'text': 'mosambi flower and fruit rot',
#     'intent': 'FruitsCitrusPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05845843830196041},
#    {'text': 'How to control flower and fruit dropping ?',
#     'intent': 'FruitsCitrusPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05383434130208031},
#    {'text': 'CITRUS CANKER',
#     'intent': 'FruitsCitrusPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03650798678951803},
#    {'text': 'Ask for Junagadh Agri Uni Contact number\t0285- 2672080 (SSK)',
#     'intent': 'FruitsCustardAppleCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.1070552631402307},
#    {'text': 'How to control flower and fruit dropping ?',
#     'intent': 'FruitsGuavaCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05383434130208031},
#    {'text': 'guava varieties management',
#     'intent': 'FruitsGuavaCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05489589328399693},
#    {'text': 'How to control flower and fruit dropping ?',
#     'intent': 'FruitsGuavaPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05383434130208031},
#    {'text': 'Growth Delay',
#     'intent': 'FruitsLitchiPlantProtection',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.0455567585844249},
#    {'text': 'WEED MANAGEMENTIN MANGO',
#     'intent': 'FruitsMangoCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.07111294874375801},
#    {'text': 'MARKET  INFORMATION OF MANGO',
#     'intent': 'FruitsMangoMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0684024319016357},
#    {'text': 'termite management in mango',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05317455321340241},
#    {'text': 'mango thrips',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.0730870860458051},
#    {'text': 'MANGO FRUIT BORER',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.0749034571997488},
#    {'text': 'MANGO MEALY BUGS MANAGEMENT',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05378054076022605},
#    {'text': 'MANAGEMENT OF FRUIT BORE IN MANGO',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05191952778595268},
#    {'text': 'insecticide of mango',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05960043794890816},
#    {'text': 'plant protection',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.057372723527065},
#    {'text': 'Insect in Mango',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.06040937423026183},
#    {'text': 'Fruit cracking',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.06578748628187034},
#    {'text': 'How to control flower and fruit dropping ?',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05383434130208031},
#    {'text': 'aam me fal gir ja raha hai',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.06381174872079722},
#    {'text': 'MANGO FRUIT FLY MANAGEMENT',
#     'intent': 'FruitsMangoPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.06023825429778402},
#    {'text': 'MANGO VARIETIES',
#     'intent': 'FruitsMangoSeedsandPlantingMaterial',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.06528478304171846},
#    {'text': 'sucking prst management in mosambi',
#     'intent': 'FruitsMosambiPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.05121028533434013},
#    {'text': 'papaya sucking pest management',
#     'intent': 'FruitsPapayaAgricultureMechanization',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04504535277458538},
#    {'text': 'papaya sucking pest management',
#     'intent': 'FruitsPapayaAgricultureMechanization',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04504535277458538},
#    {'text': 'WEED MANAGEMENT IN PAPAYA',
#     'intent': 'FruitsPapayaCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.049071951299141964},
#    {'text': 'PAPAYA WEED MANAGEMENT',
#     'intent': 'FruitsPapayaCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.048397183218452065},
#    {'text': 'papaya flower drop management',
#     'intent': 'FruitsPapayaCulturalPractices',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.05316036562139215},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FruitsPapayaCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'fertilizer use managemnt',
#     'intent': 'FruitsPapayaFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.13139818064011435},
#    {'text': 'NUTRIENT MANAGEMENT',
#     'intent': 'FruitsPapayaNutrientManagement',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.04417282932098638},
#    {'text': 'SUCKING PEST MANAGEMENT IN PAPAYA',
#     'intent': 'FruitsPapayaPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.046174781883680266},
#    {'text': 'POMEGRANATE FERTILIZER MANAGEMENT AT 4 MONTH STAGE',
#     'intent': 'FruitsPomegranateFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.05310915706793925},
#    {'text': 'aphid control',
#     'intent': 'FruitsPomegranatePlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.031888053658297784},
#    {'text': 'Ask about Gernal information',
#     'intent': 'FruitsSapotaCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'ASK ABOUT HORTICULTURAL NURSERY CONTACT NUMBER',
#     'intent': 'FruitsSapotaSeedsandPlantingMaterial',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.0789726403544457},
#    {'text': 'information about aloe veera marketing',
#     'intent': 'MedicinalandAromaticPlantsAloeVeraCulturalPractices',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.06873380332539542},
#    {'text': 'Ask about General  information',
#     'intent': 'MedicinalandAromaticPlantsNeemNurseryManagement',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.06589539113280773},
#    {'text': 'Information regarding weather ?',
#     'intent': 'MilletsBarnyardMilletKundiraivlliSawanFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Information regarding weather ?',
#     'intent': 'MilletsBarnyardMilletKundiraivlliSawanFieldPreparation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.608963923575998},
#    {'text': 'Ask about Gernal information',
#     'intent': 'MilletsBarnyardMilletKundiraivlliSawanPlantProtection',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'MARKET TOLL FREE NUMBER',
#     'intent': 'MilletsKodoMilletKodaraVaraguMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.07859419700702835},
#    {'text': 'MARKET INFORMATION OF MAIZE',
#     'intent': 'MilletsMaizeMakkaMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.03712828286638972},
#    {'text': 'MAIAE MARKET INFORMATION',
#     'intent': 'MilletsMaizeMakkaMarketInformation',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.05549463223338872},
#    {'text': 'ASKING ABOUT INSECTISIDE',
#     'intent': 'MilletsMaizeMakkaPlantProtection',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.10472277387181488},
#    {'text': 'Downey Mildew of Maize',
#     'intent': 'MilletsMaizeMakkaPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.1620385715085199},
#    {'text': 'Farmer wants to know about varieties of maize crop?',
#     'intent': 'MilletsMaizeMakkaVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.10380707094471965},
#    {'text': 'Good variety of maize',
#     'intent': 'MilletsMaizeMakkaVarieties',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.055412049284034155},
#    {'text': 'Good variety of maize-',
#     'intent': 'MilletsMaizeMakkaVarieties',
#     'predicted': 'OthersOthersWeather',
# ...
#     'confidence': 0.038216105668068955},
#    {'text': 'Ask about sowing time of chilli and tomato',
#     'intent': 'VegetablesChilliesCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.105148776563616},
#    {'text': 'Ask about Gernal information',
#     'intent': 'VegetablesChilliesCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'chilli market information :',
#     'intent': 'VegetablesChilliesMarketInformation',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.05258509563709419},
#    {'text': 'CHILI MARKET INFORMATION',
#     'intent': 'VegetablesChilliesMarketInformation',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.031199550734198916},
#    {'text': 'ASKING ABOUT THE  NUTREINT MANAGEMENT IN CHILLIS',
#     'intent': 'VegetablesChilliesNutrientManagement',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.12831939458459504},
#    {'text': 'CHILLI NUTRIENT MANAGEMENT',
#     'intent': 'VegetablesChilliesNutrientManagement',
#     'predicted': 'VegetablesChilliesPlantProtection',
#     'confidence': 0.0290506767948232},
#    {'text': 'early blight management in chillie',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.04446955051357178},
#    {'text': 'chilli powdermildew management',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesChilliesPlantProtection',
#     'confidence': 0.0359090721461423},
#    {'text': 'CHILLI SUCKING PEST',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.03780645855443733},
#    {'text': 'PROTECTION IN CHILLI',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.03637389270522271},
#    {'text': 'Chilli thrips',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.0429147941426193},
#    {'text': 'LEAF CURL IN CHILLI',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.039683516422944216},
#    {'text': 'how to control fungal disease in chillie crop ?',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04073706549528827},
#    {'text': 'sucking pest management in chillie',
#     'intent': 'VegetablesChilliesPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.03758420313186794},
#    {'text': 'sowing time of chilli',
#     'intent': 'VegetablesChilliesSeedsandPlantingMaterial',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0741374749576966},
#    {'text': 'COW PEA VARITIEES',
#     'intent': 'VegetablesCowpeaVegetableCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.07066503409448932},
#    {'text': 'SUCKING PEST MANAGEMENT IN COWPEA',
#     'intent': 'VegetablesCowpeaVegetablePlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.03178204738327166},
#    {'text': 'CUCUMBER NUTRIENT MANAGEMENT',
#     'intent': 'VegetablesCucumberFieldPreparation',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03205987554700351},
#    {'text': 'seed of curry leaves availibility',
#     'intent': 'VegetablesCurryLeafSeedsandPlantingMaterial',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.04728088439786368},
#    {'text': 'asking about lablab bushy type suitable varieties',
#     'intent': 'VegetablesLabLabCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.08074304869704373},
#    {'text': 'LAB LAB SOWING TIME( KHARIF )',
#     'intent': 'VegetablesLabLabPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.0689899717673576},
#    {'text': 'Information regarding control of fruit cracking in long melon ?',
#     'intent': 'VegetablesLongMelonBioPesticidesandBioFertilizers',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.188919516875315},
#    {'text': 'Ask about Gernal information',
#     'intent': 'VegetablesOnionCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'FERTILIZER APPLICATION IN ONION',
#     'intent': 'VegetablesOnionFertilizerUseandAvailability',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.07670710242173515},
#    {'text': 'GOVERNMENT SCHEMES',
#     'intent': 'VegetablesOnionGovernmentSchemes',
#     'predicted': 'OthersOthersGovernmentSchemes',
#     'confidence': 0.07382075314416209},
#    {'text': 'onion market rate',
#     'intent': 'VegetablesOnionMarketInformation',
#     'predicted': 'VegetablesChilliesPlantProtection',
#     'confidence': 0.025568182545719385},
#    {'text': 'onion plant information ?',
#     'intent': 'VegetablesOnionPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.05548628708303265},
#    {'text': 'onion sucking pest',
#     'intent': 'VegetablesOnionPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.057835438509673626},
#    {'text': 'Onion sucking pest management',
#     'intent': 'VegetablesOnionPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.05476255950003624},
#    {'text': 'Weather Information',
#     'intent': 'VegetablesOnionWeather',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.6548376571904577},
#    {'text': 'Ask about Gernal information',
#     'intent': 'VegetablesPointedGourdCulturalPractices',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'aalu me patti me kale rang ke gol  dhabbbe ban rahe hai',
#     'intent': 'VegetablesPotatoPlantProtection',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.1084858771587792},
#    {'text': 'ridge  gourd varieties',
#     'intent': 'VegetablesRidgeGourdCulturalPractices',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.045356528956885966},
#    {'text': 'RIDGE GOURD MITE MANAGEMENT',
#     'intent': 'VegetablesRidgeGourdPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.03729195676907148},
#    {'text': 'RIDGE GOURD DOWNY MILDEW MANAGEMENT',
#     'intent': 'VegetablesRidgeGourdPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.03997038559085136},
#    {'text': 'TOMATO EARLY BLIGHT MANAGEMENT',
#     'intent': 'VegetablesTomatoAgricultureMechanization',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.08387397906693582},
#    {'text': 'TOMATO EARLY BLIGHT MANAGEMENT ;',
#     'intent': 'VegetablesTomatoAgricultureMechanization',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.06867311178918019},
#    {'text': 'TOMATO WEED MANAGEMENT',
#     'intent': 'VegetablesTomatoCulturalPractices',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.05478387448603325},
#    {'text': 'tomato sowing time',
#     'intent': 'VegetablesTomatoCulturalPractices',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.0410440059999458},
#    {'text': 'TOMATO NUTRIENT MANAGEMENT',
#     'intent': 'VegetablesTomatoFertilizerUseandAvailability',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.04002857488135825},
#    {'text': 'NUTRIENT MANAGEMENT IN TOMATO',
#     'intent': 'VegetablesTomatoNutrientManagement',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.048979850196081295},
#    {'text': 'TOMATO NUTRIENT MANAGEMENT',
#     'intent': 'VegetablesTomatoNutrientManagement',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.04002857488135825},
#    {'text': 'tomato whitefly control',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.09812949759743622},
#    {'text': 'tomato sucking pest management',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.08974594715190784},
#    {'text': 'tomato white fly management',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.0757807450431104},
#    {'text': 'leaf hopper in tomato',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.0876743456943833},
#    {'text': 'management of tomato jassid',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.06713259717602867},
#    {'text': 'tomato sucking pest management',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.08974594715190784},
#    {'text': 'TOMATO ROOT ROT',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.13409363029311477},
#    {'text': 'MITE MANAGEMENT IN TOMATO',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.08185834149505189},
#    {'text': 'TOMATO SUCKING PEST MANAGEMENT',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.08974594715190784},
#    {'text': 'EARLY BLIGHT MANAGEMENT IN  TOMATO',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.06593816631822375},
#    {'text': 'tomato sukkking pest',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.09445416437913305},
#    {'text': 'TOMATO RED MITES MANAGEMENT',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.09454287997479094},
#    {'text': 'SUCKING PEST MANAGEMENT IN TOMATO',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.07199364440907575},
#    {'text': 'ROOT ROT IN TAMATO',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.07322811763605964},
#    {'text': 'plant protection of tomato',
#     'intent': 'VegetablesTomatoPlantProtection',
#     'predicted': 'VegetablesTomatoPlantProtection',
#     'confidence': 0.07630477841395895},
#    {'text': 'ASKING ABOUT CULTIVATION OF TOMATO UNDER PLASTIC HOUSE',
#     'intent': 'VegetablesTomatoPlasticulture',
#     'predicted': 'OthersOthersWeather',
#     'confidence': 0.18756669083331545},
#    {'text': 'Ask about Gernal information',
#     'intent': 'VegetablesWatermelonPlantProtection',
#     'predicted': 'OthersOthersCulturalPractices',
#     'confidence': 0.09341556861142038},
#    {'text': 'Ask about fungus problem in Root',
#     'intent': 'VegetablesWatermelonPlantProtection',
#     'predicted': 'OthersOthersPlantProtection',
#     'confidence': 0.037723454459373994},
#    {'text': 'watermelon flower drop management',
#     'intent': 'VegetablesWatermelonPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.04743233128865086},
#    {'text': 'watermelon sukking pest',
#     'intent': 'VegetablesWatermelonPlantProtection',
#     'predicted': 'FruitsMangoPlantProtection',
#     'confidence': 0.045184080816551946}],
#   'report': '                                                                      precision    recall  f1-score   support\n\n                                AnimalBovineCowBuffaloAnimalBreeding       0.00      0.00      0.00         1\n                             AnimalBovineCowBuffaloDiseaseManagement       0.00      0.00      0.00         2\n       AnimalBovineCowBuffaloLivestockProductsProcessingandPackaging       0.00      0.00      0.00         1\n            AnimalPOULTRYFARMLivestockProductsProcessingandPackaging       0.00      0.00      0.00         1\n                               BeekeepingBeekeepingCulturalPractices       0.00      0.00      0.00         1\n                                    CerealsBarleyJauFieldPreparation       0.00      0.00      0.00         7\n                                         CerealsOatsFieldPreparation       0.00      0.00      0.00         1\n                      CerealsPaddyDhanBioPesticidesandBioFertilizers       0.00      0.00      0.00         2\n                                   CerealsPaddyDhanCulturalPractices       0.00      0.00      0.00         1\n                        CerealsPaddyDhanFertilizerUseandAvailability       0.00      0.00      0.00         2\n                                   CerealsPaddyDhanGovernmentSchemes       0.00      0.00      0.00         1\n                                     CerealsPaddyDhanPlantProtection       0.48      1.00      0.65        14\n                                               CerealsPaddyDhanSeeds       0.00      0.00      0.00         2\n                                         CerealsPaddyDhanSoilTesting       0.00      0.00      0.00         2\n                                CerealsPaddyDhanSowingTimeandWeather       0.00      0.00      0.00         2\n                                           CerealsPaddyDhanVarieties       0.40      0.53      0.46        15\n                                             CerealsPaddyDhanWeather       0.00      0.00      0.00         5\n                                    CerealsTriticaleFieldPreparation       0.00      0.00      0.00         1\n                          CerealsWheatBioPesticidesandBioFertilizers       0.00      0.00      0.00         1\n                                               CerealsWheatVarieties       0.00      0.00      0.00         1\n                                                 CerealsWheatWeather       0.00      0.00      0.00        13\n                          CondimentsandSpicesGingerCulturalPractices       0.00      0.00      0.00         1\n                   CondimentsandSpicesGingerSeedsandPlantingMaterial       0.00      0.00      0.00         1\n                        CondimentsandSpicesTurmericMarketInformation       0.00      0.00      0.00         2\n                 CondimentsandSpicesTurmericSeedsandPlantingMaterial       0.00      0.00      0.00         1\n                 FiberCropsCottonKapasBioPesticidesandBioFertilizers       0.00      0.00      0.00         5\n                              FiberCropsCottonKapasCulturalPractices       0.00      0.00      0.00         1\n                   FiberCropsCottonKapasFertilizerUseandAvailability       0.00      0.00      0.00         6\n                               FiberCropsCottonKapasFieldPreparation       0.00      0.00      0.00         1\n                              FiberCropsCottonKapasMarketInformation       0.94      1.00      0.97        16\n                             FiberCropsCottonKapasNutrientManagement       0.00      0.00      0.00         1\n                                FiberCropsCottonKapasPlantProtection       1.00      0.57      0.73         7\n                                    FiberCropsCottonKapasSoilTesting       0.00      0.00      0.00         1\n                           FiberCropsCottonKapasSowingTimeandWeather       0.00      0.00      0.00         1\n                                      FiberCropsCottonKapasVarieties       0.83      0.88      0.86  ...
#   'precision': 0.3800174767406066,
#   'f1_score': 0.4367698797739567,
#   'accuracy': 0.554},
#  'entity_evaluation': {'CRFEntityExtractor': {'report': '              precision    recall  f1-score   support\n\n   no_entity       1.00      1.00      1.00      4459\n\n   micro avg       1.00      1.00      1.00      4459\n   macro avg       1.00      1.00      1.00      4459\nweighted avg       1.00      1.00      1.00      4459\n',
#    'precision': 1.0,
#    'f1_score': 1.0,
#    'accuracy': 1.0}}}

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet
from rasa_core.policies import FallbackPolicy, KerasPolicy, MemoizationPolicy
from rasa_core.agent import Agent

# Use a Fallback action in case model is unable to understand the question
fallback = FallbackPolicy(fallback_action_name="utter_OthersOthersGovernmentSchemes",
                          core_threshold=0.3,
                          nlu_threshold=0.3)

agent = Agent('agri.yml', policies=[MemoizationPolicy(), KerasPolicy(), fallback])

# Load query definitions
training_data = agent.load_data('query.md')

agent.train(
    training_data,epochs=50,
    validation_split=0.2
)

agent.persist('models/dialogue')
# Out:
# Processed Story Blocks: 100%|████████████████████████████████████████| 189/189 [00:00<00:00, 1181.24it/s, # trackers=1]
# Processed Story Blocks: 100%|████████████████████████████████████████| 189/189 [00:00<00:00, 453.23it/s, # trackers=20]
# Processed Story Blocks: 100%|████████████████████████████████████████| 189/189 [00:00<00:00, 292.30it/s, # trackers=20]
# Processed Story Blocks: 100%|████████████████████████████████████████| 189/189 [00:00<00:00, 386.94it/s, # trackers=20]
# Processed trackers:   4%|█▌                                       | 438/11340 [00:02<00:49, 218.90it/s, # actions=1001]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  10%|████                                    | 1157/11340 [00:05<00:47, 215.43it/s, # actions=2425]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  16%|██████▍                                 | 1829/11340 [00:08<00:45, 211.00it/s, # actions=3770]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  22%|████████▉                               | 2539/11340 [00:11<00:41, 212.72it/s, # actions=5179]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  28%|███████████▍                            | 3227/11340 [00:14<00:37, 215.52it/s, # actions=6565]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  34%|█████████████▋                          | 3888/11340 [00:17<00:29, 249.80it/s, # actions=7908]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  41%|████████████████▍                       | 4646/11340 [00:20<00:28, 237.98it/s, # actions=9406]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  47%|██████████████████▍                    | 5348/11340 [00:24<00:24, 244.62it/s, # actions=10774]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  53%|████████████████████▋                  | 6021/11340 [00:27<00:27, 194.52it/s, # actions=12107]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  59%|███████████████████████▏               | 6731/11340 [00:30<00:21, 215.92it/s, # actions=13547]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  65%|█████████████████████████▌             | 7419/11340 [00:33<00:19, 200.26it/s, # actions=14906]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  71%|███████████████████████████▊           | 8089/11340 [00:36<00:15, 205.71it/s, # actions=16247]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  78%|██████████████████████████████▍        | 8836/11340 [00:40<00:11, 225.69it/s, # actions=17747]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  84%|████████████████████████████████▊      | 9559/11340 [00:43<00:08, 212.47it/s, # actions=19187]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  90%|██████████████████████████████████▍   | 10261/11340 [00:46<00:04, 225.41it/s, # actions=20564]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  96%|████████████████████████████████████▋ | 10931/11340 [00:49<00:01, 262.31it/s, # actions=21912]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers: 100%|██████████████████████████████████████| 11340/11340 [00:51<00:00, 222.02it/s, # actions=22681]
# Processed actions: 1968it [00:01, 1407.09it/s, # examples=2007]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed actions: 6562it [00:04, 1534.74it/s, # examples=6562]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Processed actions: 10612it [00:07, 1381.57it/s, # examples=10701]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed actions: 14894it [00:10, 1334.82it/s, # examples=14984]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed actions: 19163it [00:14, 1272.65it/s, # examples=19213]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed actions: 22681it [00:16, 1343.25it/s, # examples=22681]
# Processed trackers:   1%|▌                                         | 141/11340 [00:00<00:50, 222.44it/s, # actions=427]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:   8%|███▏                                     | 891/11340 [00:03<00:46, 223.08it/s, # actions=1909]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  14%|█████▌                                  | 1582/11340 [00:06<00:43, 226.47it/s, # actions=3291]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  20%|████████▏                               | 2305/11340 [00:09<00:37, 242.72it/s, # actions=4741]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  27%|██████████▊                             | 3081/11340 [00:13<00:32, 250.50it/s, # actions=6285]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  36%|██████████████▍                         | 4082/11340 [00:17<00:31, 231.52it/s, # actions=8269]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  42%|████████████████▉                       | 4795/11340 [00:20<00:28, 230.34it/s, # actions=9678]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  50%|███████████████████▋                   | 5720/11340 [00:24<00:25, 222.16it/s, # actions=11542]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  58%|██████████████████████▊                | 6616/11340 [00:28<00:20, 232.56it/s, # actions=13333]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  64%|█████████████████████████              | 7300/11340 [00:31<00:16, 242.10it/s, # actions=14683]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  72%|████████████████████████████▏          | 8178/11340 [00:35<00:14, 218.63it/s, # actions=16403]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  80%|███████████████████████████████        | 9026/11340 [00:38<00:09, 232.75it/s, # actions=18103]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers:  87%|██████████████████████████████████     | 9887/11340 [00:42<00:06, 229.16it/s, # actions=19833]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Processed trackers: 100%|██████████████████████████████████████| 11340/11340 [00:48<00:00, 233.85it/s, # actions=22681]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_3 (Masking)          (None, 5, 382)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                53120
# _________________________________________________________________
# dense_3 (Dense)              (None, 191)               6303
# _________________________________________________________________
# activation_3 (Activation)    (None, 191)               0
# =================================================================
# Total params: 59,423
# Trainable params: 59,423
# Non-trainable params: 0
# _________________________________________________________________
# Train on 18144 samples, validate on 4537 samples
# Epoch 1/50
# 18144/18144 [==============================] - 6s 337us/step - loss: 3.2211 - acc: 0.4985 - val_loss: 2.8053 - val_acc: 0.4898
# Epoch 2/50
# 18144/18144 [==============================] - 5s 275us/step - loss: 2.7652 - acc: 0.5057 - val_loss: 2.6928 - val_acc: 0.4933
# Epoch 3/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 2.6290 - acc: 0.5169 - val_loss: 2.6880 - val_acc: 0.4902
# Epoch 4/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 2.4779 - acc: 0.5805 - val_loss: 2.4961 - val_acc: 0.5028
# Epoch 5/50
# 18144/18144 [==============================] - 4s 239us/step - loss: 2.1915 - acc: 0.6634 - val_loss: 2.0325 - val_acc: 0.5982
# Epoch 6/50
# 18144/18144 [==============================] - 4s 237us/step - loss: 1.7684 - acc: 0.7787 - val_loss: 1.4948 - val_acc: 0.8764
# Epoch 7/50
# 18144/18144 [==============================] - 4s 240us/step - loss: 1.2977 - acc: 0.8623 - val_loss: 0.9630 - val_acc: 0.9623
# Epoch 8/50
# 18144/18144 [==============================] - 4s 237us/step - loss: 0.9745 - acc: 0.9057 - val_loss: 0.5901 - val_acc: 0.9907
# Epoch 9/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 0.7125 - acc: 0.9365 - val_loss: 0.3408 - val_acc: 0.9947
# Epoch 10/50
# 18144/18144 [==============================] - 4s 239us/step - loss: 0.5306 - acc: 0.9582 - val_loss: 0.1707 - val_acc: 0.9965
# Epoch 11/50
# 18144/18144 [==============================] - 4s 241us/step - loss: 0.4121 - acc: 0.9690 - val_loss: 0.0851 - val_acc: 0.9978
# Epoch 12/50
# 18144/18144 [==============================] - 4s 239us/step - loss: 0.3267 - acc: 0.9732 - val_loss: 0.0448 - val_acc: 0.9967
# Epoch 13/50
# 18144/18144 [==============================] - 4s 246us/step - loss: 0.2718 - acc: 0.9753 - val_loss: 0.0301 - val_acc: 0.9967
# Epoch 14/50
# 18144/18144 [==============================] - 4s 242us/step - loss: 0.2312 - acc: 0.9764 - val_loss: 0.0231 - val_acc: 0.9969
# Epoch 15/50
# 18144/18144 [==============================] - 4s 241us/step - loss: 0.2081 - acc: 0.9762 - val_loss: 0.0201 - val_acc: 0.9963
# Epoch 16/50
# 18144/18144 [==============================] - 5s 249us/step - loss: 0.1805 - acc: 0.9778 - val_loss: 0.0178 - val_acc: 0.9974
# Epoch 17/50
# 18144/18144 [==============================] - 4s 242us/step - loss: 0.1692 - acc: 0.9777 - val_loss: 0.0168 - val_acc: 0.9965
# Epoch 18/50
# 18144/18144 [==============================] - 4s 247us/step - loss: 0.1659 - acc: 0.9764 - val_loss: 0.0152 - val_acc: 0.9978
# Epoch 19/50
# 18144/18144 [==============================] - 5s 251us/step - loss: 0.1524 - acc: 0.9781 - val_loss: 0.0139 - val_acc: 0.9980
# Epoch 20/50
# 18144/18144 [==============================] - 4s 247us/step - loss: 0.1366 - acc: 0.9797 - val_loss: 0.0128 - val_acc: 0.9980
# Epoch 21/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 0.1276 - acc: 0.9809 - val_loss: 0.0122 - val_acc: 0.9978
# Epoch 22/50
# 18144/18144 [==============================] - 5s 257us/step - loss: 0.1396 - acc: 0.9778 - val_loss: 0.0116 - val_acc: 0.9982
# Epoch 23/50
# 18144/18144 [==============================] - 4s 247us/step - loss: 0.1264 - acc: 0.9802 - val_loss: 0.0098 - val_acc: 0.9989
# Epoch 24/50
# 18144/18144 [==============================] - 4s 239us/step - loss: 0.1387 - acc: 0.9771 - val_loss: 0.0091 - val_acc: 0.9993
# Epoch 25/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 0.1237 - acc: 0.9795 - val_loss: 0.0078 - val_acc: 0.9996
# Epoch 26/50
# 18144/18144 [==============================] - 4s 238us/step - loss: 0.1202 - acc: 0.9800 - val_loss: 0.0074 - val_acc: 0.9996
# Epoch 27/50
# 18144/18144 [==============================] - 4s 244us/step - loss: 0.1175 - acc: 0.9802 - val_loss: 0.0069 - val_acc: 0.9996
# Epoch 28/50
# 18144/18144 [==============================] - 5s 260us/step - loss: 0.1281 - acc: 0.9777 - val_loss: 0.0065 - val_acc: 0.9991
# Epoch 29/50
# 18144/18144 [==============================] - 5s 271us/step - loss: 0.1308 - acc: 0.9774 - val_loss: 0.0062 - val_acc: 0.9996
# Epoch 30/50
# 18144/18144 [==============================] - 5s 269us/step - loss: 0.1108 - acc: 0.9809 - val_loss: 0.0054 - val_acc: 0.9996
# Epoch 31/50
# 18144/18144 [==============================] - 5s 250us/step - loss: 0.1173 - acc: 0.9794 - val_loss: 0.0050 - val_acc: 0.9998
# Epoch 32/50
# 18144/18144 [==============================] - 4s 243us/step - loss: 0.1173 - acc: 0.9796 - val_loss: 0.0045 - val_acc: 1.0000
# Epoch 33/50
# 18144/18144 [==============================] - 4s 246us/step - loss: 0.1101 - acc: 0.9807 - val_loss: 0.0038 - val_acc: 1.0000
# Epoch 34/50
# 18144/18144 [==============================] - 5s 254us/step - loss: 0.1159 - acc: 0.9798 - val_loss: 0.0036 - val_acc: 1.0000
# Epoch 35/50
# 18144/18144 [==============================] - 5s 265us/step - loss: 0.1143 - acc: 0.9799 - val_loss: 0.0033 - val_acc: 1.0000
# Epoch 36/50
# 18144/18144 [==============================] - 4s 248us/step - loss: 0.1158 - acc: 0.9795 - val_loss: 0.0029 - val_acc: 1.0000
# Epoch 37/50
# 18144/18144 [==============================] - 5s 257us/step - loss: 0.1216 - acc: 0.9786 - val_loss: 0.0028 - val_acc: 1.0000
# Epoch 38/50
# 18144/18144 [==============================] - 4s 236us/step - loss: 0.1227 - acc: 0.9781 - val_loss: 0.0026 - val_acc: 1.0000
# Epoch 39/50
# 18144/18144 [==============================] - 4s 234us/step - loss: 0.1123 - acc: 0.9800 - val_loss: 0.0023 - val_acc: 1.0000
# Epoch 40/50
# 18144/18144 [==============================] - 4s 236us/step - loss: 0.1117 - acc: 0.9803 - val_loss: 0.0022 - val_acc: 1.0000
# Epoch 41/50
# 18144/18144 [==============================] - 4s 236us/step - loss: 0.1173 - acc: 0.9793 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 42/50
# 18144/18144 [==============================] - 4s 236us/step - loss: 0.1205 - acc: 0.9787 - val_loss: 0.0021 - val_acc: 1.0000
# Epoch 43/50
#  9408/18144 [==============>...............] - ETA: 1s - loss: 0.1192 - acc: 0.9791

# %% [markdown]
# ### Start Agricultural chatbot

# %%
from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory)

# %%
print("Type your question here...")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Type your question here...
# insect in kapas
# WEATHER REPORT DRY WEATHER NO CHANCE OF RAINFALL IN YOUR AREA
# hello
# WEATHER REPORT DRY WEATHER NO CHANCE OF RAINFALL IN YOUR AREA
# hi
# WEATHER REPORT DRY WEATHER NO CHANCE OF RAINFALL IN YOUR AREA
# cotton
# contact agriculture officer
# weather
# insect
# contact agriculture officer
# insect in cotton
# contact agriculture officer
# stop

# %% [markdown]
# ### Next steps
# This model has a low accuracy level currently and it needs to be enhanced by scaling the training questions and answers and tuning model hyperparameters
